# %% [markdown]
# <a href="https://colab.research.google.com/github/saurater/ciencia_de_dados/blob/main/R_Aula_5_An%C3%A1lise_Explanat%C3%B3ria_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 5  - Análise Exploratória de Dados com R#
#
# ## AED - Capitulo 01 - Prof. Máiron Chaves ###
#
# **Versão em Python disponível em:**

# %% [markdown]
# #Não executar a linha abaixo no Colab

# %%
rm(list=ls(all=TRUE))

# %% [markdown]
# #Cria o data frame contendo o historico de vendas do cafe

# %%
dados <- data.frame(
  Vendas_Cafe = c(18, 20, 23, 23, 23, 23, 24, 25, 26, 26, 26, 26, 27,
28, 28, 29, 29, 30, 30, 31, 31, 33, 34, 35, 38, 39, 41, 44, 44, 46),
 Preco_Cafe = c(4.77, 4.67, 4.75, 4.74, 4.63, 4.56, 4.59, 4.75, 4.75, 4.49,
 4.41, 4.32, 4.68, 4.66, 4.42, 4.71, 4.66, 4.46, 4.36, 4.47, 4.43,
 4.4, 4.61, 4.09, 3.73, 3.89, 4.35, 3.84, 3.81, 3.79),
Promocao = c("Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao", "Nao",
"Sim", "Nao", "Sim", "Nao", "Nao", "Sim", "Sim", "Nao", "Sim", "Sim",
 "Sim", "Nao", "Nao", "Sim", "Sim", "Sim", "Nao", "Sim", "Sim", 
 "Sim", "Sim", "Sim"),
 Preco_Leite = c(4.74, 4.81, 4.36, 4.29, 4.17, 4.66, 4.73, 4.11, 4.21, 4.25,
 4.62, 4.53, 4.44, 4.19, 4.37, 4.29, 4.57, 4.21, 4.77, 4, 4.31,
 4.34, 4.05, 4.73, 4.07, 4.75, 4, 4.15, 4.34, 4.15) 
 )

# %%
dados
# Out:
#    Vendas_Cafe Preco_Cafe Promocao Preco_Leite
# 1  18          4.77       Nao      4.74
# 2  20          4.67       Nao      4.81
# 3  23          4.75       Nao      4.36
# 4  23          4.74       Nao      4.29
# 5  23          4.63       Nao      4.17
# 6  23          4.56       Nao      4.66
# 7  24          4.59       Nao      4.73
# 8  25          4.75       Nao      4.11
# 9  26          4.75       Sim      4.21
# 10 26          4.49       Nao      4.25
# 11 26          4.41       Sim      4.62
# 12 26          4.32       Nao      4.53
# 13 27          4.68       Nao      4.44
# 14 28          4.66       Sim      4.19
# 15 28          4.42       Sim      4.37
# 16 29          4.71       Nao      4.29
# 17 29          4.66       Sim      4.57
# 18 30          4.46       Sim      4.21
# 19 30          4.36       Sim      4.77
# 20 31          4.47       Nao      4.00
# 21 31          4.43       Nao      4.31
# 22 33          4.40       Sim      4.34
# 23 34          4.61       Sim      4.05
# 24 35          4.09       Sim      4.73
# 25 38          3.73       Nao      4.07
# 26 39          3.89       Sim      4.75
# 27 41          4.35       Sim      4.00
# 28 44          3.84       Sim      4.15
# 29 44          3.81       Sim      4.34
# 30 46          3.79       Sim      4.15

# %% [markdown]
# #Visualiza a Média (mean) e outras Estatísticas Descritivas das Variáveis

# %%
summary(dados)
# Out:
#   Vendas_Cafe      Preco_Cafe      Promocao          Preco_Leite
#  Min.   :18.00   Min.   :3.730   Length:30          Min.   :4.000
#  1st Qu.:25.25   1st Qu.:4.353   Class :character   1st Qu.:4.175
#  Median :28.50   Median :4.480   Mode  :character   Median :4.325
#  Mean   :30.00   Mean   :4.426                      Mean   :4.374
#  3rd Qu.:33.75   3rd Qu.:4.668                      3rd Qu.:4.607
#  Max.   :46.00   Max.   :4.770                      Max.   :4.810

# %% [markdown]
# #Visualiza Desvio Padrão (Standard Deviation) das Variáveis

# %%
sd(dados$Vendas_Cafe)
# Out:
# [1] 7.310833

# %%
sd(dados$Preco_Cafe)
# Out:
# [1] 0.3220568

# %%
sd(dados$Preco_Leite)
# Out:
# [1] 0.2558082

# %% [markdown]
# #Visualização atraves de um Histograma a Distribuicao da Variável Preco_Cafe

# %%
hist(dados$Preco_Cafe)
# Out:
# Plot with title “Histogram of dados$Preco_Cafe”

# %% [markdown]
# # Customizando o Histograma

# %%
hist(dados$Preco_Cafe,
 col = 'blue',
 main = 'Distribuicao dos Preços Praticados para o Café')
# Out:
# Plot with title “Distribuicao dos Preços Praticados para o Café”

# %% [markdown]
# #Visualização do Histograma das Três Variáveis Numéricas na mesma página

# %%
par(mfrow=c(2,2)) #Configura layout para posicionar os gráficos em duas linhas e duas colunas

# %%
hist(dados$Vendas_Cafe,
 col = 'blue',
 main = 'Distribuicao das Vendas do Café')
# Out:
# Plot with title “Distribuicao das Vendas do Café”

# %%
hist(dados$Preco_Cafe,
 col = 'blue',
 main = 'Distribuicao dos Preços do Café')
# Out:
# Plot with title “Distribuicao dos Preços do Café”

# %%
hist(dados$Preco_Leite,
 col = 'blue',
 main = 'Distribuicao dos Preços do Leite')
# Out:
# Plot with title “Distribuicao dos Preços do Leite”

# %%
dev.off() #limpa os graficos e volta o layout para configuracao normal
# Out:
# null device
#           1

# %% [markdown]
# #Visualização da Relacão entre as Vendas e o Preço do Café

# %%
plot(y = dados$Vendas_Cafe,
 x = dados$Preco_Cafe)
# Out:
# plot without title

# %% [markdown]
# #Customização  do Gráfico

# %%
plot(y = dados$Vendas_Cafe,
x = dados$Preco_Cafe,
 pch = 16,
 col = 'blue',
 xlab = 'Preço',
 ylab = 'Quantidade Vendidade',
 main = 'Relação entre o Preço e as Vendas do Café')
grid() #este comando adiciona linhas de grade ao grafico
# Out:
# Plot with title “Relação entre o Preço e as Vendas do Café”

# %% [markdown]
# #Colore os pontos em que havia promoção naquele dia
# ##Atenção: dados$Promocao convertido para Factor

# %%
plot(
 y = dados$Vendas_Cafe,
 x = dados$Preco_Cafe,
 col = as.factor(dados$Promocao),
 pch = 16,
 xlab = 'Preço',
 ylab = 'Quantidade Vendidade',
 main = 'Relação entre o Preço e as Vendas do Café'
 )
 legend(x=4.4,y=45,
 c("Promoção","Sem_Promoção"),
 col=c("red","black"),
 pch=c(16,16))
grid()
# Out:
# Plot with title “Relação entre o Preço e as Vendas do Café”

# %%
#Cria uma nova variavel informando se naquele dia vendeu acima ou abaixo da media historica
media <- mean(dados$Vendas_Cafe) #armazena a media em uma variavel
variavel <- ifelse(dados$Vendas_Cafe > media,
 'Acima_da_media',
 'Abaixo_da_media')
variavel <- factor(variavel) #converte nova variavel para factor
plot(variavel) #grafico com a qtde abaixo e acima da media
# Out:
# plot without title

# %%
table(variavel) #visualiza a qtde abaixo e acima da media
# Out:
# variavel
# Abaixo_da_media  Acima_da_media
#              19              11

# %% [markdown]
# #Gera Boxplot das Vendas

# %%
boxplot(dados$Vendas_Cafe)
# Out:
# plot without title

# %% [markdown]
# #Gera Boxplot do Preço

# %%
boxplot(dados$Preco_Cafe)
# Out:
# plot without title

# %% [markdown]
# #Gera Boxplot Comparativo das Vendas quando houve Promocão e de quando não houve

# %%
boxplot(dados$Vendas_Cafe~dados$Promocao)
# Out:
# plot without title

# %% [markdown]
# #Customizando o boxplot

# %%
boxplot(dados$Vendas_Cafe~dados$Promocao,
 col = 'gray',
 pch = 16,
 xlab = 'Promoção',
 ylab = 'Vendas',
 main = 'Vendas com Promoção vs Vendas sem Promoção')
# Out:
# Plot with title “Vendas com promoção vs Vendas sem promoção”
